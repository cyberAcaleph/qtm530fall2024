# %% [markdown]
# # <span style="color:darkblue"> Lecture 13a: Logistic Regression for Classification
#  </span>
#
# <font size = "5">

# %% [markdown]
# # <span style="color:darkblue"> I. Import Libraries </span>

# %%
# The "pandas" library is used for processing datasets
# The "numpy" is for numeric observations and random numbers
# The "matplotlib.pyplot" library is for creating graphs

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# We will use the "sklearn" package

from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.model_selection import train_test_split

# Import stats models


# This is used to create data matrices
import patsy

# %% [markdown]
# <font size = "5" >
#
# ### <span style="color:darkblue">  II. Example: Diffusion of microfinance </span>
#
# Banerjee et al. (2013) explored the effects of a marketing <br>
# campaign in rural villages in Karnataka, India, on the   <br>
# probability of requesting a microfinance loan.
#
# https://www.science.org/doi/10.1126/science.1236498
#
# We will use their data today.

# %% [markdown]
# <font size = "5">
#
# The outcome variable <br>
#
# $\quad Y_i = \text{RequestLoan}_i $

# %% [markdown]
# <font size = "5">
#
# The predictor vector:
#
# $\quad X_i = \begin{bmatrix} 1 \\ \text{ReceivedInfo}_i \\ \text{OwnsHouse}_i \\ \text{HomeNumRooms}_i \end{bmatrix} $

# %% [markdown]
# # <span style="color:darkblue"> III. Prepare Data </span>

# %%
dataset = pd.read_csv("data_raw/microfinance_data.csv")

# %% [markdown]
# <font size = "5">
#
# Read microfinance data

# %%
dataset = pd.read_csv("data_raw/microfinance_data.csv")

# %%
dataset

# %% [markdown]
# <font size = "5">
#
# Create "y" and "X" matrices from a formula. This allows for:
#
# - Interactions
# - Factors
# - Polynomials

# %%
y, X = \
    patsy.dmatrices('request_loan ~ 1',
                       dataset)
y = np.ravel(y)

# %% [markdown]
# <font size = "5">
#
# Split the data into training and test
#
# <font size = "3">
#
# - "test_size" is a number between 0 and 1 that control the relative <br>
# proportions of the training and test datasets.
# - "random_state" is a seed that ensures that the training and test datasets <br>
# can be replicated

# %%
X_train, X_test, y_train, y_test = train_test_split(
           X, y, test_size=0.5, random_state=42)

# %% [markdown]
# # <span style="color:darkblue"> IV. Fit model and evaluate classification accuracy </span>

# %% [markdown]
# <font size = "5">
#
# Fit model on data using "Sk-learn"

# %%
model = LogisticRegression().fit(X_train,y_train)
model.coef_
# Out:
# array([[-0.77263838]])

# %% [markdown]
# <font size = "5">
#
# Obtain vector of predicted probabilites on test set
#
# 得到测试集上的预测概率向量

# %%
# Obtain predicted probabilities 获取预测概率
mat_probabilities = pd.DataFrame(model.predict_proba(X_test))

# Obtain probabilites for the event 1 获取事件1发生的概率
# (This is the second column of "mat_probabilities")
vec_probabilities = mat_probabilities.iloc[:,1]

# Display results
plt.hist(x = vec_probabilities)
plt.xlabel("Predicted Probability")
plt.ylabel("Frequency")
plt.title("Predicted Probabilities on Test Set")
# Out:
# Text(0.5, 1.0, 'Predicted Probabilities on Test Set')

# %% [markdown]
# <font size = "5">
#
# Classifying observations
#
# - If probability is higher than 0.15 classify as 1
# - Can change threshold
#
# 分类的观察
#
# —如果概率大于0.15，分类为1
#
# -可以更改阈值

# %%
bins_y = [0,0.15, 1]
labels_y = [0,1]

predicted_labels = pd.cut(vec_probabilities,
                              bins = bins_y,
                              right = True,
                              labels = labels_y)

# %% [markdown]
# <font size = "5">
#
# Obtain a confusion matrix
#
# 得到一个混淆矩阵
#
# 混淆矩阵 (Confusion Matrix)：显示了预测值和实际值的对应关系，包括真阳性、假阳性、真阴性、假阴性。

# %%
cm = confusion_matrix(y_test, predicted_labels)
cm
# Out:
# array([[   0, 3891],
#        [   0,  908]])

# %% [markdown]
# <font size = "5">
#
# Display confusion matrix

# %%
fig, ax = plt.subplots(figsize=(5, 5))
ax.imshow(cm)
ax.grid(False)
ax.xaxis.set(ticks=(0, 1), ticklabels=('Predicted 0s', 'Predicted 1s'))
ax.yaxis.set(ticks=(0, 1), ticklabels=('Actual 0s', 'Actual 1s'))
ax.set_ylim(1.5, -0.5)
for i in range(2):
    for j in range(2):
        ax.text(j, i, cm[i, j], ha='center', va='center')
plt.show()

# %% [markdown]
# # <span style="color:darkblue"> IV. Exercises </span>
#
# <font size = "5">
#
# Try it yourself
#
# - Change the classification threshold
# - How does this change the classification accuracy?
# - Create a for-loop evaluating the accuracy over different thresholds

# %%
# Write your own code
bins_y = [0,0.17551, 1]
labels_y = [0,1]

predicted_labels = pd.cut(vec_probabilities,
                              bins = bins_y,
                              right = True,
                              labels = labels_y)
cm = confusion_matrix(y_test, predicted_labels)
cm
# Out:
# array([[   0, 3891],
#        [   0,  908]])

# %%
import numpy as np
import pandas as pd
from sklearn.metrics import confusion_matrix, accuracy_score

thresholds = np.arange(0.0, 1.05, 0.01)  # 从 0.0 到 1.0，每隔 0.05 一个阈值
accuracies = []  # 存储每个阈值的准确率

for threshold in thresholds:
    # 根据当前阈值生成预测标签
    predicted_labels = (vec_probabilities >= threshold).astype(int)
    
    # 计算混淆矩阵
    cm = confusion_matrix(y_test, predicted_labels)
    print(f"Threshold: {threshold}")
    print("Confusion Matrix:\n", cm)
    
    # 计算准确率
    accuracy = accuracy_score(y_test, predicted_labels)
    accuracies.append(accuracy)
    print(f"Accuracy: {accuracy}\n")

# 输出每个阈值对应的准确率
for threshold, accuracy in zip(thresholds, accuracies):
    print(f"Threshold: {threshold:.2f} - Accuracy: {accuracy:.4f}")
# Out:
# Threshold: 0.0
# Confusion Matrix:
#  [[   0 3891]
#  [   0  908]]
# Accuracy: 0.18920608460095853
#
# Threshold: 0.01
# Confusion Matrix:
#  [[   0 3891]
#  [   0  908]]
# Accuracy: 0.18920608460095853
#
# Threshold: 0.02
# Confusion Matrix:
#  [[   0 3891]
#  [   0  908]]
# Accuracy: 0.18920608460095853
#
# Threshold: 0.03
# Confusion Matrix:
#  [[   0 3891]
#  [   0  908]]
# Accuracy: 0.18920608460095853
#
# Threshold: 0.04
# Confusion Matrix:
#  [[   0 3891]
#  [   0  908]]
# Accuracy: 0.18920608460095853
#
# Threshold: 0.05
# Confusion Matrix:
#  [[   0 3891]
#  [   0  908]]
# Accuracy: 0.18920608460095853
#
# Threshold: 0.06
# Confusion Matrix:
#  [[   0 3891]
#  [   0  908]]
# Accuracy: 0.18920608460095853
#
# Threshold: 0.07
# Confusion Matrix:
#  [[   0 3891]
#  [   0  908]]
# Accuracy: 0.18920608460095853
#
# Threshold: 0.08
# Confusion Matrix:
#  [[   0 3891]
#  [   0  908]]
# Accuracy: 0.18920608460095853
#
# Threshold: 0.09
# Confusion Matrix:
#  [[   0 3891]
#  [   0  908]]
# Accuracy: 0.18920608460095853
#
# Threshold: 0.1
# Confusion Matrix:
#  [[   0 3891]
#  [   0  908]]
# Accuracy: 0.18920608460095853
#
# Threshold: 0.11
# Confusion Matrix:
#  [[   0 3891]
#  [   0  908]]
# Accuracy: 0.18920608460095853
#
# Threshold: 0.12
# Confusion Matrix:
#  [[   0 3891]
#  [   0  908]]
# Accuracy: 0.18920608460095853
#
# Threshold: 0.13
# Confusion Matrix:
#  [[   0 3891]
#  [   0  908]]
# Accuracy: 0.18920608460095853
#
# Threshold: 0.14
# Confusion Matrix:
#  [[   0 3891]
#  [   0  908]]
# Accuracy: 0.18920608460095853
#
# Threshold: 0.15
# Confusion Matrix:
#  [[   0 3891]
#  [   0  908]]
# Accuracy: 0.18920608460095853
#
# Threshold: 0.16
# Confusion Matrix:
#  [[   0 3891]
#  [   0  908]]
# Accuracy: 0.18920608460095853
#
# Threshold: 0.17
# Confusion Matrix:
#  [[   0 3891]
#  [   0  908]]
# Accuracy: 0.18920608460095853
#
# Threshold: 0.18
# Confusion Matrix:
#  [[3891    0]
#  [ 908    0]]
# Accuracy: 0.8107939153990414
#
# Threshold: 0.19
# Confusion Matrix:
#  [[3891    0]
#  [ 908    0]]
# Accuracy: 0.8107939153990414
#
# Threshold: 0.2
# Confusion Matrix:
#  [[3891    0]
#  [ 908    0]]
# Accuracy: 0.8107939153990414
#
# Threshold: 0.21
# Confusion Matrix:
#  [[3891    0]
#  [ 908    0]]
# Accuracy: 0.8107939153990414
#
# Threshold: 0.22
# Confusion Matrix:
#  [[3891    0]
#  [ 908    0]]
# Accuracy: 0.8107939153990414
#
# Threshold: 0.23
# Confusion Matrix:
#  [[3891    0]
#  [ 908    0]]
# Accuracy: 0.8107939153990414
#
# Threshold: 0.24
# Confusion Matrix:
#  [[3891    0]
#  [ 908    0]]
# Accuracy: 0.8107939153990414
#
# Threshold: 0.25
# Confusion Matrix:
#  [[3891    0]
#  [ 908    0]]
# Accuracy: 0.8107939153990414
#
# Threshold: 0.26
# Confusion Matrix:
#  [[3891    0]
#  [ 908    0]]
# Accuracy: 0.8107939153990414
#
# Threshold: 0.27
# Confusion Matrix:
#  [[3891    0]
#  [ 908    0]]
# Accuracy: 0.8107939153990414
#
# Threshold: 0.28
# Confusion Matrix:
#  [[3891    0]
#  [ 908    0]]
# Accuracy: 0.8107939153990414
#
# Threshold: 0.29
# Confusion Matrix:
#  [[3891    0]
#  [ 908    0]]
# Accuracy: 0.8107939153990414
#
# Threshold: 0.3
# Confusion Matrix:
#  [[3891    0]
#  [ 908    0]]
# Accuracy: 0.8107939153990414
#
# Threshold: 0.31
# Confusion Matrix:
#  [[3891    0]
#  [ 908    0]]
# Accuracy: 0.8107939153990414
#
# Threshold: 0.32
# Confusion Matrix:
#  [[3891    0]
#  [ 908    0]]
# Accuracy: 0.8107939153990414
#
# Threshold: 0.33
# Confusion Matrix:
#  [[3891    0]
#  [ 908    0]]
# Accuracy: 0.8107939153990414
#
# Threshold: 0.34
# Confusion Matrix:
#  [[3891    0]
#  [ 908    0]]
# Accuracy: 0.8107939153990414
#
# Threshold: 0.35000000000000003
# Confusion Matrix:
#  [[3891    0]
#  [ 908    0]]
# Accuracy: 0.8107939153990414
#
# Threshold: 0.36
# Confusion Matrix:
#  [[3891    0]
#  [ 908    0]]
# Accuracy: 0.8107939153990414
#
# Threshold: 0.37
# Confusion Matrix:
#  [[3891    0]
#  [ 908    0]]
# Accuracy: 0.8107939153990414
#
# Threshold: 0.38
# Confusion Matrix:
#  [[3891    0]
#  [ 908    0]]
# Accuracy: 0.8107939153990414
#
# Threshold: 0.39
# Confusion Matrix:
#  [[3891    0]
#  [ 908    0]]
# Accuracy: 0.8107939153990414
#
# Threshold: 0.4
# Confusion Matrix:
#  [[3891    0]
#  [ 908    0]]
# Accuracy: 0.8107939153990414
#
# Threshold: 0.41000000000000003
# Confusion Matrix:
#  [[3891    0]
#  [ 908    0]]
# Accuracy: 0.8107939153990414
#
# Threshold: 0.42
# Confusion Matrix:
#  [[3891    0]
#  [ 908    0]]
# Accuracy: 0.8107939153990414
#
# Threshold: 0.43
# Confusion Matrix:
#  [[3891    0]
#  [ 908    0]]
# Accuracy: 0.8107939153990414
#
# Threshold: 0.44
# Confusion Matrix:
#  [[3891    0]
#  [ 908    0]]
# Accuracy: 0.8107939153990414
#
# Threshold: 0.45
# Confusion Matrix:
#  [[3891    0]
#  [ 908    0]]
# Accuracy: 0.8107939153990414
#
# Threshold: 0.46
# Confusion Matrix:
#  [[3891    0]
#  [ 908    0]]
# Accuracy: 0.8107939153990414
#
# Threshold: 0.47000000000000003
# Confusion Matrix:
#  [[3891    0]
#  [ 908    0]]
# Accuracy: 0.8107939153990414
#
# Threshold: 0.48
# Confusion Matrix:
#  [[3891    0]
#  [ 908    0]]
# Accuracy: 0.8107939153990414
#
# Threshold: 0.49
# Confusion Matrix:
#  [[3891    0]
#  [ 908    0]]
# Accuracy: 0.8107939153990414
#
# Threshold: 0.5
# Confusion Matrix:
#  [[3891    0]
#  [ 908    0]]
# Accuracy: 0.8107939153990414
#
# Threshold: 0.51
# Confusion Matrix:
#  [[3891    0]
#  [ 908    0]]
# Accuracy: 0.8107939153990414
#
# Threshold: 0.52
# Confusion Matrix:
#  [[3891    0]
#  [ 908    0]]
# Accuracy: 0.8107939153990414
#
# Threshold: 0.53
# Confusion Matrix:
#  [[3891    0]
#  [ 908    0]]
# Accuracy: 0.8107939153990414
#
# Threshold: 0.54
# Confusion Matrix:
#  [[3891    0]
#  [ 908    0]]
# Accuracy: 0.8107939153990414
#
# Threshold: 0.55
# Confusion Matrix:
#  [[3891    0]
#  [ 908    0]]
# Accuracy: 0.8107939153990414
#
# Threshold: 0.56
# Confusion Matrix:
#  [[3891    0]
#  [ 908    0]]
# Accuracy: 0.8107939153990414
#
# Threshold: 0.5700000000000001
# Confusion Matrix:
#  [[3891    0]
#  [ 908    0]]
# Accuracy: 0.8107939153990414
#
# Threshold: 0.58
# Confusion Matrix:
#  [[3891    0]
#  [ 908    0]]
# Accuracy: 0.8107939153990414
#
# Threshold: 0.59
# Confusion Matrix:
#  [[3891    0]
#  [ 908    0]]
# Accuracy: 0.8107939153990414
#
# Threshold: 0.6
# Confusion Matrix:
#  [[3891    0]
#  [ 908    0]]
# Accuracy: 0.8107939153990414
#
# Threshold: 0.61
# Confusion Matrix:
#  [[3891    0]
#  [ 908    0]]
# Accuracy: 0.8107939153990414
#
# Threshold: 0.62
# Confusion Matrix:
#  [[3891    0]
#  [ 908    0]]
# Accuracy: 0.8107939153990414
#
# Threshold: 0.63
# Confusion Matrix:
#  [[3891    0]
#  [ 908    0]]
# Accuracy: 0.8107939153990414
#
# Threshold: 0.64
# Confusion Matrix:
#  [[3891    0]
#  [ 908    0]]
# Accuracy: 0.8107939153990414
#
# Threshold: 0.65
# Confusion Matrix:
#  [[3891    0]
#  [ 908    0]]
# Accuracy: 0.8107939153990414
#
# Threshold: 0.66
# Confusion Matrix:
#  [[3891    0]
#  [ 908    0]]
# Accuracy: 0.8107939153990414
#
# Threshold: 0.67
# Confusion Matrix:
#  [[3891    0]
#  [ 908    0]]
# Accuracy: 0.8107939153990414
#
# Threshold: 0.68
# Confusion Matrix:
#  [[3891    0]
#  [ 908    0]]
# Accuracy: 0.8107939153990414
#
# Threshold: 0.6900000000000001
# Confusion Matrix:
#  [[3891    0]
#  [ 908    0]]
# Accuracy: 0.8107939153990414
#
# Threshold: 0.7000000000000001
# Confusion Matrix:
#  [[3891    0]
#  [ 908    0]]
# Accuracy: 0.8107939153990414
#
# Threshold: 0.71
# Confusion Matrix:
#  [[3891    0]
#  [ 908    0]]
# Accuracy: 0.8107939153990414
#
# Threshold: 0.72
# Confusion Matrix:
#  [[3891    0]
#  [ 908    0]]
# Accuracy: 0.8107939153990414
#
# Threshold: 0.73
# Confusion Matrix:
#  [[3891    0]
#  [ 908    0]]
# Accuracy: 0.8107939153990414
#
# Threshold: 0.74
# Confusion Matrix:
#  [[3891    0]
#  [ 908    0]]
# Accuracy: 0.8107939153990414
#
# Threshold: 0.75
# Confusion Matrix:
#  [[3891    0]
#  [ 908    0]]
# Accuracy: 0.8107939153990414
#
# Threshold: 0.76
# Confusion Matrix:
#  [[3891    0]
#  [ 908    0]]
# Accuracy: 0.8107939153990414
#
# Threshold: 0.77
# Confusion Matrix:
#  [[3891    0]
#  [ 908    0]]
# Accuracy: 0.8107939153990414
#
# Threshold: 0.78
# Confusion Matrix:
#  [[3891    0]
#  [ 908    0]]
# Accuracy: 0.8107939153990414
#
# Threshold: 0.79
# Confusion Matrix:
#  [[3891    0]
#  [ 908    0]]
# Accuracy: 0.8107939153990414
#
# Threshold: 0.8
# Confusion Matrix:
#  [[3891    0]
#  [ 908    0]]
# Accuracy: 0.8107939153990414
#
# Threshold: 0.81
# Confusion Matrix:
#  [[3891    0]
#  [ 908    0]]
# Accuracy: 0.8107939153990414
#
# Threshold: 0.8200000000000001
# Confusion Matrix:
#  [[3891    0]
#  [ 908    0]]
# Accuracy: 0.8107939153990414
#
# Threshold: 0.8300000000000001
# Confusion Matrix:
#  [[3891    0]
#  [ 908    0]]
# Accuracy: 0.8107939153990414
#
# Threshold: 0.84
# Confusion Matrix:
#  [[3891    0]
#  [ 908    0]]
# Accuracy: 0.8107939153990414
#
# Threshold: 0.85
# Confusion Matrix:
#  [[3891    0]
#  [ 908    0]]
# Accuracy: 0.8107939153990414
#
# Threshold: 0.86
# Confusion Matrix:
#  [[3891    0]
#  [ 908    0]]
# Accuracy: 0.8107939153990414
#
# Threshold: 0.87
# Confusion Matrix:
#  [[3891    0]
#  [ 908    0]]
# Accuracy: 0.8107939153990414
#
# Threshold: 0.88
# Confusion Matrix:
#  [[3891    0]
#  [ 908    0]]
# Accuracy: 0.8107939153990414
#
# Threshold: 0.89
# Confusion Matrix:
#  [[3891    0]
#  [ 908    0]]
# Accuracy: 0.8107939153990414
#
# Threshold: 0.9
# Confusion Matrix:
#  [[3891    0]
#  [ 908    0]]
# Accuracy: 0.8107939153990414
#
# Threshold: 0.91
# Confusion Matrix:
#  [[3891    0]
#  [ 908    0]]
# Accuracy: 0.8107939153990414
#
# Threshold: 0.92
# Confusion Matrix:
#  [[3891    0]
#  [ 908    0]]
# Accuracy: 0.8107939153990414
#
# Threshold: 0.93
# Confusion Matrix:
#  [[3891    0]
#  [ 908    0]]
# Accuracy: 0.8107939153990414
#
# Threshold: 0.9400000000000001
# Confusion Matrix:
#  [[3891    0]
#  [ 908    0]]
# Accuracy: 0.8107939153990414
#
# Threshold: 0.9500000000000001
# Confusion Matrix:
#  [[3891    0]
#  [ 908    0]]
# Accuracy: 0.8107939153990414
#
# Threshold: 0.96
# Confusion Matrix:
#  [[3891    0]
#  [ 908    0]]
# Accuracy: 0.8107939153990414
#
# Threshold: 0.97
# Confusion Matrix:
#  [[3891    0]
#  [ 908    0]]
# Accuracy: 0.8107939153990414
#
# Threshold: 0.98
# Confusion Matrix:
#  [[3891    0]
#  [ 908    0]]
# Accuracy: 0.8107939153990414
#
# Threshold: 0.99
# Confusion Matrix:
#  [[3891    0]
#  [ 908    0]]
# Accuracy: 0.8107939153990414
#
# Threshold: 1.0
# Confusion Matrix:
#  [[3891    0]
#  [ 908    0]]
# Accuracy: 0.8107939153990414
#
# Threshold: 1.01
# Confusion Matrix:
#  [[3891    0]
#  [ 908    0]]
# Accuracy: 0.8107939153990414
#
# Threshold: 1.02
# Confusion Matrix:
#  [[3891    0]
#  [ 908    0]]
# Accuracy: 0.8107939153990414
#
# Threshold: 1.03
# Confusion Matrix:
#  [[3891    0]
#  [ 908    0]]
# Accuracy: 0.8107939153990414
#
# Threshold: 1.04
# Confusion Matrix:
#  [[3891    0]
#  [ 908    0]]
# Accuracy: 0.8107939153990414
#
# Threshold: 0.00 - Accuracy: 0.1892
# Threshold: 0.01 - Accuracy: 0.1892
# Threshold: 0.02 - Accuracy: 0.1892
# Threshold: 0.03 - Accuracy: 0.1892
# Threshold: 0.04 - Accuracy: 0.1892
# Threshold: 0.05 - Accuracy: 0.1892
# Threshold: 0.06 - Accuracy: 0.1892
# Threshold: 0.07 - Accuracy: 0.1892
# Threshold: 0.08 - Accuracy: 0.1892
# Threshold: 0.09 - Accuracy: 0.1892
# Threshold: 0.10 - Accuracy: 0.1892
# Threshold: 0.11 - Accuracy: 0.1892
# Threshold: 0.12 - Accuracy: 0.1892
# Threshold: 0.13 - Accuracy: 0.1892
# Threshold: 0.14 - Accuracy: 0.1892
# Threshold: 0.15 - Accuracy: 0.1892
# Threshold: 0.16 - Accuracy: 0.1892
# Threshold: 0.17 - Accuracy: 0.1892
# Threshold: 0.18 - Accuracy: 0.8108
# Threshold: 0.19 - Accuracy: 0.8108
# Threshold: 0.20 - Accuracy: 0.8108
# Threshold: 0.21 - Accuracy: 0.8108
# Threshold: 0.22 - Accuracy: 0.8108
# Threshold: 0.23 - Accuracy: 0.8108
# Threshold: 0.24 - Accuracy: 0.8108
# Threshold: 0.25 - Accuracy: 0.8108
# Threshold: 0.26 - Accuracy: 0.8108
# Threshold: 0.27 - Accuracy: 0.8108
# Threshold: 0.28 - Accuracy: 0.8108
# Threshold: 0.29 - Accuracy: 0.8108
# Threshold: 0.30 - Accuracy: 0.8108
# Threshold: 0.31 - Accuracy: 0.8108
# Threshold: 0.32 - Accuracy: 0.8108
# Threshold: 0.33 - Accuracy: 0.8108
# Threshold: 0.34 - Accuracy: 0.8108
# Threshold: 0.35 - Accuracy: 0.8108
# Threshold: 0.36 - Accuracy: 0.8108
# Threshold: 0.37 - Accuracy: 0.8108
# Threshold: 0.38 - Accuracy: 0.8108
# Threshold: 0.39 - Accuracy: 0.8108
# Threshold: 0.40 - Accuracy: 0.8108
# Threshold: 0.41 - Accuracy: 0.8108
# Threshold: 0.42 - Accuracy: 0.8108
# Threshold: 0.43 - Accuracy: 0.8108
# Threshold: 0.44 - Accuracy: 0.8108
# Threshold: 0.45 - Accuracy: 0.8108
# Threshold: 0.46 - Accuracy: 0.8108
# Threshold: 0.47 - Accuracy: 0.8108
# Threshold: 0.48 - Accuracy: 0.8108
# Threshold: 0.49 - Accuracy: 0.8108
# Threshold: 0.50 - Accuracy: 0.8108
# Threshold: 0.51 - Accuracy: 0.8108
# Threshold: 0.52 - Accuracy: 0.8108
# Threshold: 0.53 - Accuracy: 0.8108
# Threshold: 0.54 - Accuracy: 0.8108
# Threshold: 0.55 - Accuracy: 0.8108
# Threshold: 0.56 - Accuracy: 0.8108
# Threshold: 0.57 - Accuracy: 0.8108
# Threshold: 0.58 - Accuracy: 0.8108
# Threshold: 0.59 - Accuracy: 0.8108
# Threshold: 0.60 - Accuracy: 0.8108
# Threshold: 0.61 - Accuracy: 0.8108
# Threshold: 0.62 - Accuracy: 0.8108
# Threshold: 0.63 - Accuracy: 0.8108
# Threshold: 0.64 - Accuracy: 0.8108
# Threshold: 0.65 - Accuracy: 0.8108
# Threshold: 0.66 - Accuracy: 0.8108
# Threshold: 0.67 - Accuracy: 0.8108
# Threshold: 0.68 - Accuracy: 0.8108
# Threshold: 0.69 - Accuracy: 0.8108
# Threshold: 0.70 - Accuracy: 0.8108
# Threshold: 0.71 - Accuracy: 0.8108
# Threshold: 0.72 - Accuracy: 0.8108
# Threshold: 0.73 - Accuracy: 0.8108
# Threshold: 0.74 - Accuracy: 0.8108
# Threshold: 0.75 - Accuracy: 0.8108
# Threshold: 0.76 - Accuracy: 0.8108
# Threshold: 0.77 - Accuracy: 0.8108
# Threshold: 0.78 - Accuracy: 0.8108
# Threshold: 0.79 - Accuracy: 0.8108
# Threshold: 0.80 - Accuracy: 0.8108
# Threshold: 0.81 - Accuracy: 0.8108
# Threshold: 0.82 - Accuracy: 0.8108
# Threshold: 0.83 - Accuracy: 0.8108
# Threshold: 0.84 - Accuracy: 0.8108
# Threshold: 0.85 - Accuracy: 0.8108
# Threshold: 0.86 - Accuracy: 0.8108
# Threshold: 0.87 - Accuracy: 0.8108
# Threshold: 0.88 - Accuracy: 0.8108
# Threshold: 0.89 - Accuracy: 0.8108
# Threshold: 0.90 - Accuracy: 0.8108
# Threshold: 0.91 - Accuracy: 0.8108
# Threshold: 0.92 - Accuracy: 0.8108
# Threshold: 0.93 - Accuracy: 0.8108
# Threshold: 0.94 - Accuracy: 0.8108
# Threshold: 0.95 - Accuracy: 0.8108
# Threshold: 0.96 - Accuracy: 0.8108
# Threshold: 0.97 - Accuracy: 0.8108
# Threshold: 0.98 - Accuracy: 0.8108
# Threshold: 0.99 - Accuracy: 0.8108
# Threshold: 1.00 - Accuracy: 0.8108
# Threshold: 1.01 - Accuracy: 0.8108
# Threshold: 1.02 - Accuracy: 0.8108
# Threshold: 1.03 - Accuracy: 0.8108
# Threshold: 1.04 - Accuracy: 0.8108

# %% [markdown]
# <font size = "5">
#
# Try it yourself
#
# - Add interactions between "Own rooms" and other independent variables
# - Does this improve the classification accuracy?

# %%
# 定义公式，包含 Own_rooms 与其他变量的交互项
formula = 'request_loan ~ owns_house * (received_info + home_numrooms)'

# 使用 patsy 生成设计矩阵
y, X = patsy.dmatrices(formula, dataset, return_type='dataframe')
y = y.values.ravel()  # 将 y 转为一维数组

# 划分训练集和测试集
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# 训练逻辑回归模型
model = LogisticRegression()
model.fit(X_train, y_train)

# 预测并计算准确率
y_pred = model.predict(X_test)
accuracy = accuracy_score(y_test, y_pred)

print(f"Classification Accuracy with Interactions: {accuracy}")
# Out:
# Classification Accuracy with Interactions: 0.8097222222222222

# %% [markdown]
# <font size = "5">
